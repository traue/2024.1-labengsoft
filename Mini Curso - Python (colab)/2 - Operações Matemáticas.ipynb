# %% [markdown]
# # Operações matemáticas

# %% [markdown]
# ## Operações matemáticas

# %%
a = 5
b = 8
print(a, b)
# Out:
# 5 8

# %%
a + b
# Out:
# 13

# %%
print('A soma é', a + b)
# Out:
# A soma é 13

# %%
#outra forma de fazer:
print(f'A soma é {a + b}')
# Out:
# A soma é 13

# %%
print('A subtração é', a - b)
# Out:
# A subtração é -3

# %%
print('A divisão é', a / b)
# Out:
# A divisão é 0.625

# %%
print('A multiplicação é', a * b)
# Out:
# A multiplicação é 40

# %%
print('O resto da divisão é', 10 % 3)
# Out:
# O resto da divisão é 1

# %%
5 * 5 * 5 * 5
# Out:
# 625

# %%
print('5 elevado a 4 é', 5**4)
# Out:
# 5 elevado a 4 é 625

# %%
import math #importa o pacote "math" que possui várias funções prontas
print(math.sqrt(81))
print(math.pi)
# Out:
# 9.0
# 3.141592653589793

# %% [markdown]
# ## Arredondamento

# %%
casos_doenca = 134
numero_habitantes = 34432
casos_por_habitante = casos_doenca / numero_habitantes
print(casos_por_habitante)
# Out:
# 0.003891728624535316

# %%
round(casos_por_habitante, 6) # 6 casas decimais
# Out:
# 0.003892

# %%
print('O número de casos por habitante é de', round(casos_por_habitante, 4))
# Out:
# O número de casos por habitante é de 0.0039

# %% [markdown]
# **Exercícios de Fixação:**
#
# 1. Ler dois números inteiros, executar e mostrar o resultado das seguintes operações: adição, subtração, multiplicação e divisão
#
# 2. Efetuar o cálculo da quantidade de litros de combustível gasto em uma viagem, utilizando um automóvel que faz 12 Km por litro. Para obter o cálculo, o usuário deve fornecer o tempo gasto na viagem e a velocidade média durante ela. Desta forma, será possível obter a distância percorrida com a fórmula DISTANCIA = TEMPO * VELOCIDADE. Tendo o valor da distância, basta calcular a quantidade de litros de combustível utilizada na viagem, com a fórmula: LITROS_USADOS = DISTANCIA / 12. O programa deve apresentar os valores da velocidade média, tempo gasto na viagem, a distância percorrida e a quantidade de litros utilizada na viagem

# %% [markdown]
# Resolução = Ex 1:

# %%
#obtenção dos dados
v1 = int(input('Informe o primeiro valor: '))
v2 = int(input('Informe o segundo valor: '))
# Out:
# Informe o primeiro valor: 20
# Informe o segundo valor: 5

# %%
#cáclculos
soma = v1 + v2
subtracao = v1 - v2
multiplicacao = v1 * v2
divisao = v1 / v2

# %%
#exibição
print(f'A soma de {v1} e {v2} é {soma}')
print(f'A subratácão de {v1} e {v2} é {subtracao}')
print(f'A multiplicação de {v1} e {v2} é {multiplicacao}')
print(f'A divisão de {v1} e {v2} é {divisao}')
# Out:
# A soma de 20 e 5 é 25
# A subratácão de 20 e 5 é 15
# A multiplicação de 20 e 5 é 100
# A divisão de 20 e 5 é 4.0

# %% [markdown]
# Resolução do Exerício 2:

# %%
#obtenção dos dados:
tempoGasto = float(input('Informe o tempo (em horas) gasto na viagem: '))
velocidadeMedia = float(input('Velocidade média na viagem: '))
# Out:
# Informe o tempo (em horas) gasto na viagem: 2
# Velocidade média na viagem: 80

# %%
#cálculos:
distancia = tempoGasto * velocidadeMedia
litrosUsados = distancia / 12

# %%
#exibição dos valores:
print('A velocidade média foi de ', velocidadeMedia, 'Km/h')
print('O tempo gasto na viagem foi de ', tempoGasto , 'h')
print('A distância percorrida foi de ', distancia, 'Km')
print('Utilizou-se ', round(litrosUsados, 4), ' litros de combustível')
# Out:
# A velocidade média foi de  80.0 Km/h
# O tempo gasto na viagem foi de  2.0 h
# A distância percorrida foi de  160.0 Km
# Utilizou-se  13.3333  litros de combustível
