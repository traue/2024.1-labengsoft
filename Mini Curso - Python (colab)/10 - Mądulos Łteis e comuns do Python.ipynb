# %% [markdown]
# # Módulos úteis

# %% [markdown]
# ## Biblioteca math
#
# https://docs.python.org/3/library/math.html

# %%
import math

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
math.sin(45)
# Out:
# 0.8509035245341184

# %%
math.cos(45)
# Out:
# 0.5253219888177297

# %%
math.log(1000, 10)
# Out:
# 2.9999999999999996

# %%
math.log(32, 2)
# Out:
# 5.0

# %%
math.log(1000)
# Out:
# 6.907755278982137

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ## Biblioteca datetime
#
# https://docs.python.org/3/library/datetime.html

# %%
import datetime

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
datetime.date.today()
# Out:
# datetime.date(2022, 2, 20)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 2, 20, 20, 10, 52, 700624)

# %%
data = datetime.date(2020, 7, 10)

# %%
data
# Out:
# datetime.date(2020, 7, 10)

# %%
data.day
# Out:
# 10

# %%
data.month
# Out:
# 7

# %%
data.year
# Out:
# 2020

# %%
horario = datetime.datetime(2022, 7, 10, 7, 30, 0)

# %%
horario
# Out:
# datetime.datetime(2022, 7, 10, 7, 30)

# %%
horario.hour
# Out:
# 7

# %%
horario.minute
# Out:
# 30

# %%
horario.second
# Out:
# 0

# %% [markdown]
# ## Biblioteca random
#
# https://docs.python.org/3/library/random.html

# %%
import random

# %%
random.random()
# Out:
# 0.9256705955640956

# %%
random.randint(1,10) #entre 1 e 10
# Out:
# 6

# %%
random.randrange(0, 10, 2) #apenas múltiplos de 2, por exemplo. O terceiro parâmetro chama-se step
# Out:
# 8

# %%
random.randrange(0, 10, 3) #múltiplis de 3
# Out:
# 9

# %%
x = ['K', 'd', 13, '34-j', 'x']
x
# Out:
# ['K', 'd', 13, '34-j', 'x']

# %%
random.choice(x)
# Out:
# 13

# %% [markdown]
# ## Biblioteca time
#
# https://docs.python.org/3/library/time.html

# %%
import time as tm

# %%
tm.time()
# Out:
# 1645388236.6766446

# %%
antes = tm.time()
lista = []
for i in range(0,100000000):
  lista.append(i)
depois = tm.time()

# %%
intervalo = depois - antes
print(f'Tempo: {intervalo} segundos')
# Out:
# Tempo: 16.62398672103882 segundos

# %%
print('Finalizando...')
tm.sleep(2) # delay de 2 segundos
print('...')
tm.sleep(2)
print('Até a próxima')
# Out:
# Finalizando...
# ...
# Até a próxima
