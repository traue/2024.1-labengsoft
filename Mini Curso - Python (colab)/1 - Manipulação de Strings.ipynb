# %% [markdown]
# # Manipulação de strings

# %%
a = 'casaco'
print(a)
# Out:
# casaco

# %%
maiuscula = a.upper()
print(maiuscula)
# Out:
# CASACO

# %%
minuscula = maiuscula.lower()
print(minuscula)
# Out:
# casaco

# %%
capital = a.capitalize()
print(capital)
# Out:
# Casaco

# %%
metade_palavra = a[0:4]
print(metade_palavra)
# Out:
# casa

# %%
ultimas_letras = a[3:]
print(ultimas_letras)
# Out:
# aco

# %%
b = a.replace('aco', 'inha')
print(a)
print(b)
# Out:
# casaco
# casinha

# %%
c = a.replace('o', 'a')
print(c)
# Out:
# casaca

# %%
c.find('s')
# Out:
# 2

# %%
c.find('a')
# Out:
# 1

# %%
c.find('b')
# Out:
# -1

# %%
e = ' casaco '
print(len(e))
# Out:
# 8

# %%
f = e.strip()
print(f)
# Out:
# casaco

# %%
print(len(f))
# Out:
# 6

# %%
n1 = 14
n2 = 16

# %%
print(f'Dividindo {n1} por {n2} o resultado é {n1/n2}') #o f serve para "format"
# Out:
# Dividindo 14 por 16 o resultado é 0.875
