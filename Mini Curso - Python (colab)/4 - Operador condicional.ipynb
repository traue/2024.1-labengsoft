# %% [markdown]
# # Operador condicional

# %%
5 > 3
# Out:
# True

# %%
if 5 > 3:
  print('5 é maior que 3')
#print('teste')
# Out:
# 5 é maior que 3

# %%
if 5 > 4:
  print('5 é maior')
else:
  print('5 não é maior')
# Out:
# 5 é maior

# %%
# verificar se n é igual a 3 ou 4 ou 8, usando o ELIF
n = 1
if n == 4:
  print('n é igual a 4')
elif n == 3:
  print('n é igual a 3')
elif n == 8:
  print('n é igual a 8')
else:
  print('n não é igual a 4 nem 3, nem 8')
# Out:
# n não é igual a 4 nem 3, nem 8

# %%
x = 1
y = 5
if (x > 1) or (y % 2 == 0):
  print('x é maior que 1 e y é par')
else:
  print('Uma ou nenhuma das condições foram satisfeitas')
# Out:
# Uma ou nenhuma das condições foram satisfeitas

# %% [markdown]
# # Exercícios de Fixação

# %% [markdown]
# 1 Leia a idade do usuário e classifique-o em:
#     - Criança – 0 a 12 anos
#     - Adolescente – 13 a 17 anos
#     - Adulto – acima de 18 anos
#     - Se o usuário digitar um número negativo, mostrar a mensagem que a idade é inválida
#
#
#
# 2. Calcular a média de um aluno que cursou a disciplina de Programação I, a partir da leitura das notas M1, M2 e M3; passando por um cálculo da média aritmética. Após a média calculada, devemos anunciar se o aluno foi aprovado, reprovado ou pegou exame
#     - Se a média estiver entre 0.0 e 4.0, o aluno está reprovado
#     - Se a média estiver entre 4.1 e 6.0, o aluno pegou exame
#     - Se a média for maior do que 6.0, o aluno está aprovado
#     - Se o aluno pegou exame, deve ser lida a nota do exame. Se a nota do exame for maior do que 6.0, está aprovado, senão; está reprovado

# %% [markdown]
# Resolução, exercício 1:

# %%
#leitura:
idade = int(input('Digite a idade: '))
# Out:
# Digite a idade: 34

# %%
if idade >= 0 and idade <= 12:
  print('Criança')
elif idade > 12 and idade <= 18:
  print('Adolescente')
elif idade > 18:
  print('Adulto')
else:
  print('Idade inválida')
# Out:
# Adulto

# %% [markdown]
# Resolução - Ex. 2

# %%
# Leitura dos dados nas variáveis
m1 = float(input('Digite a nota 1: '))
m2 = float(input('Digite a nota 2: '))
m3 = float(input('Digite a nota 3: '))
# Out:
# Digite a nota 1: 5
# Digite a nota 2: 4
# Digite a nota 3: 5

# %%
#cálculo da média
media = (m1 + m2 + m3) / 3
print('A média é: ', media)
# Out:
# A média é:  4.666666666666667

# %%
#impressões
if media >= 0.0 and media <= 4.0:
  print('Aluno reprovado')
elif media >= 4.1 and media <= 6.0:
  exame = float(input('Digite a nota do exame'))
  if exame >= 6.0:
    print('Aprovado no exame')
  else:
    print('Reprovado no exame')
else:
  print('Aluno aprovado')
# Out:
# Digite a nota do exame6
# Aprovado no exame
