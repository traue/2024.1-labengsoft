# %% [markdown]
# # Módulos personalizados

# %%
import funcoes_uteis as ut

# %%
ut.soma(1, 2, 3)
# Out:
# 6

# %%
ut.multiplica(3, 2, 2)
# Out:
# 12

# %%
ut.isPalindromo('abc')
# Out:
# False

# %%
ut.isPalindromo('abccba')
# Out:
# True

# %%
t = 'abccba'

# %%
t[::-1]
# Out:
# 'abccba'

# %%
t1 = 'abc'
t1[::-1]

# %%
ut.divisao(10,2) #implementar - cuidado para não perder pois o colab não salva o arquivo
# Out:
# 5.0

# %% [markdown]
# # Execício de fixação

# %% [markdown]
# Crie um arquivo .py com duas funções
# - Função para ler um string (recebe como parâmetro uma mensagem e retorna o que o usuário digitou)
# - Função para ler um número float (recebe como parâmetro uma mensagem e retorna o que o usuário digitou)
#
# Importe o arquivo e teste

# %%
# fazer externamente:

def leitura_string(mensagem):
  return(input(mensagem))
  
def leitura_float(mensagem):
  return(float(input(mensagem)))

# %%
#Execução

nome = leitura_string('Me diz seu nome: ')
peso = leitura_float('Me diz seu peso: ')
# Out:
# Me diz seu nome: Thiago
# Me diz seu peso: 150

# %%
print(nome)
print(peso)
# Out:
# Thiago
# 150.0
