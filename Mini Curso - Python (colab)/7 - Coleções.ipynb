# %% [markdown]
# # Coleções

# %% [markdown]
# ## Tuplas

# %%
tupla = ('Fulano', 'Ciclano', 'Beltrano')

# %%
tupla
# Out:
# ('Fulano', 'Ciclano', 'Beltrano')

# %%
tupla[0]
# Out:
# 'Fulano'

# %%
tupla.index('Fulano') #tentar outros para mostrar o erro quando não encontrar
# Out:
# 0

# %%
for elemento in tupla:
  print(elemento)
# Out:
# Fulano
# Ciclano
# Beltrano

# %% [markdown]
# ## Listas

# %%
lista1 = ['Fulano', 'Beltrano', 'Ciclano']
lista2 = ['Thiago', 'Traue']

# %%
lista3 = lista1 + lista2
print(lista3)
# Out:
# ['Fulano', 'Beltrano', 'Ciclano', 'Thiago', 'Traue']

# %%
lista2
# Out:
# ['Thiago', 'Traue']

# %%
lista4 = lista2 * 2
print(lista4)
# Out:
# ['Thiago', 'Traue', 'Thiago', 'Traue']

# %%
lista1[0:2] #do 0 ao 1
# Out:
# ['Fulano', 'Beltrano']

# %%
lista1
# Out:
# ['Fulano', 'Beltrano', 'Ciclano']

# %%
lista1[1:5]
# Out:
# ['Beltrano', 'Ciclano']

# %%
lista1.append('Batman')
print(lista1)
# Out:
# ['Fulano', 'Beltrano', 'Ciclano', 'Batman']

# %%
lista1.remove('Batman')
print(lista1)
# Out:
# ['Fulano', 'Beltrano', 'Ciclano']

# %%
del(lista1) #sai da memória

# %%
print(lista2) # tentar imprimir a lista 1 para mostrar que foi deletada
# Out:
# ['Thiago', 'Traue']

# %%
for item in lista4:
  print(item)
# Out:
# Thiago
# Traue
# Thiago
# Traue

# %% [markdown]
# ## Dicionários (como maps)

# %%
estoque = {'Baterias': 8, 'Telas': 10, 'Câmeras': 9}

# %%
estoque['Telas']
# Out:
# 10

# %%
estoque['Cabos'] = 6 #acrescenta

# %%
print(estoque)
# Out:
# {'Baterias': 8, 'Telas': 10, 'Câmeras': 9, 'Rhodnius montenegrensis': 11, 'Cabos': 6}

# %%
del(estoque)['Câmeras']
print(estoque)
# Out:
# {'Baterias': 8, 'Telas': 10, 'Cabos': 6}

# %%
estoque.items()
# Out:
# dict_items([('Baterias', 8), ('Telas', 10), ('Cabos', 6)])

# %%
estoque.keys()
# Out:
# dict_keys(['Baterias', 'Telas', 'Cabos'])

# %%
estoque.values()
# Out:
# dict_values([8, 10, 6])

# %%
estoque2 = {'Fones': 2, 'Protetores': 50, 'Baterias': 20}
print(estoque2)
# Out:
# {'Fones': 2, 'Protetores': 50, 'Baterias': 20}

# %%
estoque.update(estoque2) #cria itens que não existem e atualiza os existentes
print(estoque)
# Out:
# {'Baterias': 20, 'Telas': 10, 'Cabos': 6, 'Fones': 2, 'Protetores': 50}

# %%
estoque.items()
# Out:
# dict_items([('Baterias', 20), ('Telas', 10), ('Cabos', 6), ('Fones', 2), ('Protetores', 50)])

# %%
for material, num_materiais in estoque.items():
  print(f'Item em estoque: {material}, quantidade: {num_materiais}')
# Out:
# Item em estoque: Baterias, quantidade: 20
# Item em estoque: Telas, quantidade: 10
# Item em estoque: Cabos, quantidade: 6
# Item em estoque: Fones, quantidade: 2
# Item em estoque: Protetores, quantidade: 50

# %% [markdown]
# ## Conjuntos (set)

# %% [markdown]
# Os sets são uma coleção de itens desordenada, parcialmente imutável e que não podem conter elementos duplicados. Além disso, os sets são utilizados, normalmente, com operações matemáticas de união, interseção e diferença simétrica,

# %%
biomeleculas = ('proteína', 'ácidos nucleicos', 'carboidrato', 'lipídeo',
                'ácidos nucleicos', 'carboidrato', 'carboidrato', 'carboidrato')

# %%
print(biomeleculas)
# Out:
# ('proteína', 'ácidos nucleicos', 'carboidrato', 'lipídeo', 'ácidos nucleicos', 'carboidrato', 'carboidrato', 'carboidrato')

# %%
print(set(biomeleculas)) #traz apenas elementos não repetidos
# Out:
# {'carboidrato', 'ácidos nucleicos', 'proteína', 'lipídeo'}

# %%
c1 = {1,2,3,4,5}
c2 = {3,4,5,6,7}
c3 = c1.intersection(c2)

# %%
print(c3)
# Out:
# {3, 4, 5}

# %%
c1.difference(c2)
# Out:
# {1, 2}

# %%
c2.difference(c1)
# Out:
# {6, 7}
